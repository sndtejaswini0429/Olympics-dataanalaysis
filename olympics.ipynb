# %% [markdown]
# <a href="https://colab.research.google.com/github/sndtejaswini0429/Olympics-dataanalaysis/blob/main/olympics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fd=open('summer.csv','r')
txt=fd.read()
fd.close()

# %%
txt

# %%
details = txt.split("\n")
details

# %%
import pandas as pd
df = pd.read_csv('summer.csv')
print(df.head())
print(df.tail())

# %%
df

# %% [markdown]
# ## **1. In how many cities Summer Olympics is held so far?**

# %%
var = df["City"].value_counts()
print(var)
print("number of cities in Olympics held so far is:" ,len(var))
# Out:
# London                   3567
# Athens                   2149
# Los Angeles              2074
# Beijing                  2042
# Sydney                   2015
# Atlanta                  1859
# Barcelona                1705
# Seoul                    1546
# Paris                    1396
# Moscow                   1387
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1031
# Tokyo                    1010
# Helsinki                  889
# Melbourne / Stockholm     885
# Stockholm                 885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: City, dtype: int64
# number of cities in Olympics held so far is: 22

# %% [markdown]
# ## **2. Which sport is having most number of Gold Medals so far? (Top 5)**

# %%
v = df['Sport'].loc[df['Medal'] == 'Gold']
#print(v)
#print(v.max())
v.value_counts()
#v.value_counts().head().plot.bar()
# Out:
# Aquatics             1421
# Athletics            1215
# Rowing                890
# Gymnastics            820
# Fencing               552
# Football              503
# Hockey                486
# Sailing               412
# Wrestling             391
# Shooting              384
# Cycling               371
# Basketball            342
# Canoe / Kayak         334
# Volleyball            332
# Handball              321
# Equestrian            320
# Boxing                239
# Weightlifting         200
# Archery               126
# Judo                  123
# Baseball              111
# Tennis                 92
# Rugby                  78
# Softball               60
# Modern Pentathlon      60
# Table Tennis           46
# Badminton              46
# Tug of War             36
# Taekwondo              32
# Lacrosse               28
# Canoe                  27
# Polo                   22
# Golf                   13
# Cricket                12
# Skating                 9
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
sports = ['Aquatics' , 'Athletics' , 'Rowing' , 'Gymnastics' , 'Fencing' ]
g_medal = [1421,1215,890,820,552]
plt.bar(sports,g_medal)
plt.xlabel('sports')
plt.ylabel('no of gold medals')
plt.title('top5 sports with more gold medals')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **3. Which sport is having most number of medals so far? (Top 5)**

# %%
va = df['Sport'].loc[df['Medal'] !=0]
print(va.value_counts())
#print(va.max())
# Out:
# Aquatics             4170
# Athletics            3638
# Rowing               2667
# Gymnastics           2307
# Fencing              1613
# Football             1497
# Hockey               1422
# Wrestling            1212
# Shooting             1150
# Sailing              1109
# Cycling              1105
# Basketball           1012
# Canoe / Kayak        1002
# Volleyball            994
# Handball              973
# Equestrian            939
# Boxing                894
# Weightlifting         593
# Judo                  491
# Baseball              335
# Archery               329
# Tennis                296
# Rugby                 192
# Softball              180
# Modern Pentathlon     180
# Table Tennis          144
# Badminton             144
# Taekwondo             112
# Tug of War             94
# Canoe                  81
# Polo                   66
# Lacrosse               59
# Golf                   30
# Ice Hockey             27
# Skating                27
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
sports = ['Aquatics' , 'Athletics' , 'Rowing' , 'Gymnastics' , 'Fencing' ]
medal = [4170,3638,2667,2307,1613]
plt.bar(sports,medal)
plt.xlabel('sports')
plt.ylabel('no of medals')
plt.title('top5 sports with more medals')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **4. Which player has won most number of medals? (Top 5)**

# %%
vas = df['Athlete'].loc[df['Medal'] !=0]
print(vas.value_counts())
#print(vas.max())
# Out:
# PHELPS, Michael              22
# LATYNINA, Larisa             18
# ANDRIANOV, Nikolay           15
# SHAKHLIN, Boris              13
# ONO, Takashi                 13
#                              ..
# HAPPE-KREY, Ursula            1
# DUSSERRE, Michelle Hollis     1
# WATSON, Lynette               1
# SEVOSTYANOVA, Nadezhda        1
# KRAUS, Angelika               1
# Name: Athlete, Length: 22762, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
Athlete = ['PHELPS, Michael' , 'LATYNINA, Larisa' , 'ANDRIANOV, Nikolay' , 'MANGIAROTTI, Edoardo' , 'SHAKHLIN, Boris' ]
medal = [22,18,15,13,13]
plt.bar(Athlete,medal)
plt.xlabel('Athlete')
plt.ylabel('no of medals')
plt.title('top5 Athletes with more medals')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **5. Which player has won most number Gold Medals of medals? (Top 5)**

# %%
player = df['Athlete'].loc[df['Medal'] == 'Gold']
print(player.value_counts())
#print(player.max())
# Out:
# PHELPS, Michael              18
# LEWIS, Carl                   9
# NURMI, Paavo                  9
# SPITZ, Mark                   9
# LATYNINA, Larisa              9
#                              ..
# DREVAL, Aleksandr             1
# ZHONG, Man                    1
# SELBACH, Johanna Katarina     1
# RADJENOVIC, Zdravko           1
# STILL, Megan Leanne           1
# Name: Athlete, Length: 8287, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
Athlete = ['PHELPS, Michael' , 'LEWIS, Carl' , 'NURMI, Paavo' , 'SPITZ, Mark' , 'LATYNINA, Larisa' ]
g_medal = [18,9,9,9,9]
plt.bar(Athlete,g_medal)
plt.xlabel('Athlete')
plt.ylabel('no of medals')
plt.title('top5 Athletes with more gold medals')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **6. In which year India won first Gold Medal in Summer Olympics?**

# %%
player = df.loc[df['Country'] == 'IND'] .loc[df['Medal'] == 'Gold']
#len(player)
#print(player)
x = player.head(1)
y = x['Year']
print("the year in which India won first Gold Medal in Summer Olympics is:", y)
# Out:
# the year in which India won first Gold Medal in Summer Olympics is: 5512    1928
# Name: Year, dtype: int64

# %% [markdown]
# ## **7. Which event is most popular in terms on number of players? (Top 5)**

# %%
event = df['Event'].loc[df['Athlete'] !=0]
event.value_counts().head()
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
event.value_counts().head().plot.bar()

# %% [markdown]
# ## **8. Which sport is having most female Gold Medalists? (Top 5)**

# %%
s =df.loc[df["Gender"]=="Women"].loc[df["Medal"] == "Gold"]
s.value_counts().head(5).sort_values(ascending=False)
# Out:
# Year  City         Sport      Discipline  Athlete              Country  Gender  Event                                Medal
# 2012  London       Badminton  Badminton   ZHAO, Yunlei         CHN      Women   Doubles                              Gold     2
# 1984  Los Angeles  Rowing     Rowing      O'STEEN, Shyril      USA      Women   Eight With Coxswain (8+)             Gold     1
#                                           OANCIA, Ecaterina    ROU      Women   Quadruple Sculls With Coxswain (4X)  Gold     1
#                                           OPREA-HORVAT, Elena  ROU      Women   Pair Without Coxswain (2-)           Gold     1
#                                           POPESCU, Marioara    ROU      Women   Double Sculls (2X)                   Gold     1
# dtype: int64

# %%
sp.value_counts().head().plot.bar()
